# %% [markdown]
# # Numpy - Neural Network from Scratch

# %%
# Package imports
import numpy as np

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
# Display plots inline and change default figure size
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)

# %% [markdown]
# ## Numpy basics

# %% [markdown]
# 1-dimension

# %%
a = np.array([1,2,3])
print(type(a), a)
# Out:
# <class 'numpy.ndarray'> [1 2 3]

# %%
b = np.arange(1, 5, .5)
print(b)
# Out:
# [1.  1.5 2.  2.5 3.  3.5 4.  4.5]

# %%
b.shape
# Out:
# (8,)

# %% [markdown]
# 2-dimensions

# %%
b = np.array([[1,2,3],[4,5,6]])

# %%
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
b.shape
# Out:
# (2, 3)

# %%
b[0][1]
# Out:
# 2

# %%
b.reshape((3,2))
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
b[:2, 1:3]
# Out:
# array([[2, 3],
#        [5, 6]])

# %%
b>5
# Out:
# array([[False, False, False],
#        [False, False,  True]])

# %%
b[b>5]
# Out:
# array([6])

# %%
a, b
# Out:
# (array([1, 2, 3]), array([[1, 2, 3],
#         [4, 5, 6]]))

# %%
a.shape, b.shape
# Out:
# ((3,), (2, 3))

# %%
a[np.newaxis, :]
# Out:
# array([[1, 2, 3]])

# %%
np.concatenate((a[np.newaxis, :],b), axis=0)
# Out:
# array([[1, 2, 3],
#        [1, 2, 3],
#        [4, 5, 6]])

# %%
np.vstack((a,b))
# Out:
# array([[1, 2, 3],
#        [1, 2, 3],
#        [4, 5, 6]])

# %%
np.hstack((a[:, np.newaxis],b.T))
# Out:
# array([[1, 1, 4],
#        [2, 2, 5],
#        [3, 3, 6]])

# %% [markdown]
# ## Generating a dataset

# %%
import sklearn.datasets

# %%
# Generate a dataset and plot it
np.random.seed(0)
X, y = sklearn.datasets.make_moons(200, noise=0.20)
plt.scatter(X[:,0], X[:,1], s=40, c=y, cmap=plt.cm.Spectral)

# %%
X.shape, y.shape
# Out:
# ((200, 2), (200,))

# %% [markdown]
# ## Sigmoid function

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
np.ones((1, 2))
# Out:
# array([[1., 1.]])

# %%
sigmoid(np.ones((1, 3)))
# Out:
# array([[0.73105858, 0.73105858, 0.73105858]])

# %%
x = np.linspace(-5, 5)

# %%
plt.plot(x, sigmoid(x))

# %%
def dsigmoid(y):
    return y * (1.0 - y)

# %% [markdown]
# ## Perceptron

# %%
# initialize weights randomly with mean 0 - [-1; 1]
syn0 = 2*np.random.random((2,)) - 1

# %%
for j in range(101):
    # forward propagation
    l0 = X
    l1 = sigmoid(np.dot(l0,syn0))
    
    # how much did we miss?
    l1_error = y - l1
    
    if (j % 100) == 0:
        print("Error:" + str(np.mean(np.abs(l1_error))))
    
    # backpropagation
    l1_delta = l1_error * dsigmoid(l1)
    
    # update weights
    syn0 += np.dot(l0.T,l1_delta)
# Out:
# Error:0.3811944612237661
# Error:0.18117796528169447

# %%
# Helper function to predict an output (0 or 1)
def predict(weights, x):
    prob = sigmoid(np.dot(x, weights))
    return prob.round().astype(int)

# %%
def plot_decision_boundary(pred_func):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    h = 0.01
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole gid
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Spectral)

# %%
plot_decision_boundary(lambda x: predict(syn0, x))

# %% [markdown]
# ## MLP

# %%
HIDDEN_LAYER_SIZE = 10
LEARNING_RATE = 0.1

syn0 = 2*np.random.random((2,HIDDEN_LAYER_SIZE)) - 1
syn1 = 2*np.random.random((HIDDEN_LAYER_SIZE,1)) - 1

# %%
syn0
# Out:
# array([[ 0.79751918, -0.98213747, -0.81953404,  0.2383656 , -0.2351198 ,
#         -0.80687424,  0.96986662,  0.79316251, -0.45777322, -0.0536199 ],
#        [-0.04049226,  0.01678078,  0.93451861, -0.80008297, -0.92069909,
#         -0.03258708, -0.08348198, -0.52947431, -0.88225943, -0.75231116]])

# %%
syn1
# Out:
# array([[ 0.71351049],
#        [-0.20066526],
#        [-0.23720569],
#        [-0.95605273],
#        [-0.25049459],
#        [ 0.32321458],
#        [ 0.2507164 ],
#        [ 0.82798244],
#        [ 0.3435886 ],
#        [-0.35183462]])

# %%
# %%time
for j in range(10000):
    
    # forward propagation
    l0 = X
    l1 = sigmoid(np.dot(l0,syn0))
    l2 = sigmoid(np.dot(l1,syn1))
    
    # how much did we miss?
    l2_error = y[:,np.newaxis] - l2
    
    if (j % 1000) == 0:
        print("Error:" + str(np.mean(np.abs(l2_error))))
    
    # back propagation
    l2_delta = l2_error * dsigmoid(l2)
    
    # how much did each l1 value contribute to the l2 error (according to the weights)?
    l1_error = l2_delta.dot(syn1.T)
    l1_delta = l1_error * dsigmoid(l1)
    
    
    # update weights
    syn1 += LEARNING_RATE * l1.T.dot(l2_delta)
    syn0 += LEARNING_RATE * l0.T.dot(l1_delta)
# Out:
# Error:0.47293041192630836
# Error:0.1510481881768476
# Error:0.13948508976599996
# Error:0.13529752887781135
# Error:0.13248970840929836
# Error:0.12735682831700423
# Error:0.12425407060466168
# Error:0.12075601333003087
# Error:0.11816616815401274
# Error:0.116443836267272
# Wall time: 1.49 s

# %%
# Helper function to predict an output (0 or 1)
def predict(weights, x):
    l1 = sigmoid(np.dot(x, weights[0]))
    prob = sigmoid(np.dot(l1, weights[1]))
    return prob.round().astype(int)

plot_decision_boundary(lambda x: predict((syn0, syn1), x))
