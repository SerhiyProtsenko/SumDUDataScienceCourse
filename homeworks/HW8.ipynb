# %% [markdown]
# ## HW8

# %% [markdown]
# Необхідно вирішити аналітичну задачу - спрогнозувати, хто з абонентів змінить свій тарифний план протягом наступних трьох місяців. В цілому, результат такого прогнозу використовується задля завчасної рекомендації абоненту відповідних для нього тарифних планів. І для цього:

# %% [markdown]
# Дані розміщені в папці data нашого репозиторію
#
# Файл features.csv містить опис 17 195 абонентів по 46 показникам за 6 місяців до підрахунку цільової змінної. ID – ідентифікатор абонента. MONTH_NUM_FROM_EVENT – порядковий номер місяця від формування цільової змінної (де 1 місяць описує найновіші дані, 6 місяць описує найстаріші дані). F1 – інформація про перший показник. F2 – інформація про другий показник. І т.д.
#
#
# » Файл train_set.csv – це навчальна вибірка, що складається з 12 890 абонентів. ID – ідентифікатор абонента. TARGET – індикатор зміни у абонента тарифного плану протягом наступних трьох місяців (1 – змінив, 0 – не змінив).
#
#
# » Файл test_set.csv – це тестова вибірка, що складається з 4 305 абонентів. Файл містить ID абонентів, значення цільової змінної (TARGET) яких треба спрогнозувати.
#
#
# » Файл PetrenkoP_test.txt – приклад оформленного результату. Вам необхідно вислати файл у форматі ID, TARGET, де: ID - ідентифікатор абонента, TARGET – ймовірність зміни абонентом тарифного пакету. Однак новий файл Ви маєте назвати своїм прізвищем та ім'ям.

# %% [markdown]
# На навчальній вибірці Вам потрібно побудувати модель, використовуючи дані з train_set.csv та features.csv, спрогнозувати значення цільової змінної для абонентів з test_set.csv та надіслати отримані результати у форматі PetrenkoP_test.txt. Та надіслати файл рішення.
#
# В результаті Ви маєте створити файл, який містить всього два стовпці:
#
# ID - ідентифікатор абонента,
# TARGET – ймовірність зміни абонентом тарифного плану.
#
#
# Зауважимо, що по кожному абоненту повинно бути одне значення TARGET.
#
# Важливо, що для оцінки якості роботи моделі ми будемо використовувати метрику AUC ROC.

# %% [markdown]
# Що необхідно зробити для того щоб отримати гарну оцінку?
#
# Необхідно використати всі знання, підходи та моделі, які ми вивчали протягом семестру.
#
# 1. EDA (exploratory data analysis). Перетворення датасету: або розгорнути кожного користувача в один вектор або рахувати, що кожна строка це окремий абонент не дивлячись на однакові ИД. Спробувати ці два підходи, в висновках заначити, якій краще.
#
# 2. Зменшення кількості фітч, фітча імпотанс. Генерація нових фітч.
#
# 3. Скелінг фітч за потреби
#
# 4. Аналіз вибросів
#
# 5. Використання кросс-валідації та створення моделей для класифікації, створення ансамблів моделей, бустінг, стекінг моделей.
#
# 6. Аналіз метрик якості:
#
# 7. Після аналізу метрик повернутися до п. 1,2,3, 4 та згенерувати додаткові фітчі або прибрати непотрібні
#
# 8. Зробити пошук оптимальних гіперпараметрів
#
# 9. Зробити висновки
#
# 10. Пояснити, що ви робили своїми словами
#
# Обов'язковою умовою є використання бустінгу та стекінгу моделей!!!!!
#
# Для стекінгу моделей, використовувати звичайний стекінг по фолдам, та побудування мета алгоритму по предиктам. Та також необхідно використати підхід коли предикти добавляються новими стовпчиками в початковий датасет та будується метаалгоритм на всіх даних
